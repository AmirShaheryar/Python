# %%
fruits = ["apple", "banana", "cherry", "orange", "grape"]
print(fruits[0])
print(fruits[-1])
print(fruits[1:3])
print(fruits[:3])
print(fruits[3:])
print(fruits[::3])
# Out:
# apple
# grape
# ['banana', 'cherry']
# ['apple', 'banana', 'cherry']
# ['orange', 'grape']
# ['apple', 'orange']

# %%
colors = ["red", "blue", "green"]

# %%
print(colors[0])
# Out:
# white

# %%
colors.insert(1,"red")

# %%
print(colors)
# Out:
# ['white', 'red']

# %%
colors.remove("green")

# %%
del colors[2]

# %%
evens = [x for x in range(1, 11) if x % 2 == 0] 
print(evens)
# Out:
# [2, 4, 6, 8, 10]

# %%
list1=[[1,2],[2,1]]
for i in list1:
    for j in i:
        if j%2==0:
            print(f"Hello World {j}")
# Out:
# Hello World 2
# Hello World 2

# %%
numbers = (1, 2, 3, 2, 4, 2)

# %%
print(numbers.count(3))
print(numbers.index(4))
# Out:
# 1
# 4

# %%
person=("Shaheryar",25,"Lahore")
name,age,city=person
print(f"{name}")
print(f"{age}")
# Out:
# Shaheryar
# 25

# %%
std=(("Shaheryar",21),("Ali",22),("Adnan",22))

# %%
print(std[0][0])
print(std[2][1])
# Out:
# Shaheryar
# 22

# %%
A = {1, 2, 3} 
B = {3, 4, 5}
print(A|B)
print(A&B)
print(A-B)
# Out:
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}
