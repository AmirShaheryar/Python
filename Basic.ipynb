# %%
n=input("Enter Your Name ")
age=input("Enter Your Age ")
print(f"{n} is {age} old")
# Out:
# Enter Your Name  Shaheryar
# Enter Your Age  2
# Shaheryar is 2 old

# %%
user_name=input("Enter Your Name : ")
print(f" Nice to meet you {user_name} !")
# Out:
# Enter Your Name :  Shaheryar
#  Nice to meet you Shaheryar !

# %%
food=input("Enter Your Favourite Food: ")
price=input("Enter Price : ")
print(f"A {food} costs $ {price}")
# Out:
# Enter Your Favourite Food:  Biryani
# Enter Price :  1
# A Biryani costs $ 1

# %%
age=int(input("Enter Your Age:"))
if age>=18:
    print("You are adult you can vote for sure you vote PTI")
else:
    print(f"You have to wait {18-age} years to vote")
# Out:
# Enter Your Age: 12
# You have to wait 6 years to vote

# %%
Temp=float(input("Enter Temperature in Farenheit : "))
if Temp>30:
    print("Its hot weather outside")
elif Temp>15:
    print("Its nice weather outside")
else:
    print("Its cold")
# Out:
# Enter Temperature in Farenheit :  12
# Its cold

# %%
amount=float(input("Enter Your bill payment: "))
if amount>100:
    print(f"Your Bill after discount {amount-(amount*0.1)}")
else:
    print(f"Your Bill {amount}")
# Out:
# Enter Your bill payment:  12
# Your Bill 12.0

# %%
num=int(input("Enter Number for Table: "))
for i in range(1,11):
    print(f"{num} * {i} = {num*i}")
# Out:
# Enter Number for Table:  2
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 2 * 10 = 20

# %%
def Greeting(name):
    print(f"How are You {name}")
Greeting("shaheryar")
# Out:
# How are You shaheryar
